# %% [markdown]
# # LSTM Example

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scalecast.Forecaster import Forecaster

sns.set(rc={'figure.figsize':(15,8)})

# %% [markdown]
# ## Data preprocessing

# %%
data = pd.read_csv('AirPassengers.csv',parse_dates=['Month'])

# %%
data.head()
# Out:
#        Month  #Passengers
# 0 1949-01-01          112
# 1 1949-02-01          118
# 2 1949-03-01          132
# 3 1949-04-01          129
# 4 1949-05-01          121

# %%
data.shape
# Out:
# (144, 2)

# %%
data['Month'].min()
# Out:
# Timestamp('1949-01-01 00:00:00')

# %%
data['Month'].max()
# Out:
# Timestamp('1960-12-01 00:00:00')

# %% [markdown]
# ## EDA

# %%
f = Forecaster(y=data['#Passengers'],current_dates=data['Month'])
f.plot()

# %%
f
# Out:
# Forecaster(
#     DateStartActuals=1949-01-01T00:00:00.000000000
#     DateEndActuals=1960-12-01T00:00:00.000000000
#     Freq=MS
#     ForecastLength=0
#     Xvars=[]
#     Differenced=0
#     TestLength=1
#     ValidationLength=1
#     ValidationMetric=rmse
#     ForecastsEvaluated=[]
#     CILevel=0.95
#     BootstrapSamples=100
#     CurrentEstimator=None
# )

# %%
f.plot_acf(lags=26)
plt.show()

# %%
f.plot_pacf(lags=26)
plt.show()

# %%
f.seasonal_decompose().plot()
plt.show()

# %%
stat, pval, _, _, _, _ = f.adf_test(full_res=True)
print(stat)
print(pval)
# Out:
# 0.8153688792060569
# 0.9918802434376411

# %% [markdown]
# ## LSTM Model

# %%
f.set_test_length(12)
f.generate_future_dates(12)
f.set_estimator('lstm')

# %% [markdown]
# ### Attempt 1

# %%
f.manual_forecast(call_me='lstm_default')
f.plot_test_set(ci=True)
# Out:
# 4/4 [==============================] - 2s 2ms/step - loss: 0.3574
# 5/5 [==============================] - 2s 2ms/step - loss: 0.3408

# %% [markdown]
# ### Attempt 2

# %%
f.manual_forecast(call_me='lstm_24lags',lags=24)
f.plot_test_set(ci=True)
# Out:
# 3/3 [==============================] - 1s 5ms/step - loss: 0.4275
# 4/4 [==============================] - 2s 7ms/step - loss: 0.3797

# %% [markdown]
# ### Attempt 3

# %%
f.manual_forecast(call_me='lstm_24lags_5epochs',lags=24,epochs=5,validation_split=.2,shuffle=True)
f.plot_test_set(ci=True)
# Out:
# Epoch 1/5
# 3/3 [==============================] - 3s 297ms/step - loss: 0.4704 - val_loss: 0.1930
# Epoch 2/5
# 3/3 [==============================] - 0s 18ms/step - loss: 0.4606 - val_loss: 0.1864
# Epoch 3/5
# 3/3 [==============================] - 0s 21ms/step - loss: 0.4507 - val_loss: 0.1796
# Epoch 4/5
# 3/3 [==============================] - 0s 23ms/step - loss: 0.4406 - val_loss: 0.1728
# Epoch 5/5
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4304 - val_loss: 0.1657
# Epoch 1/5
# 3/3 [==============================] - 2s 254ms/step - loss: 0.4636 - val_loss: 0.1790
# Epoch 2/5
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4554 - val_loss: 0.1733
# Epoch 3/5
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4474 - val_loss: 0.1676
# Epoch 4/5
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4396 - val_loss: 0.1621
# Epoch 5/5
# 3/3 [==============================] - 0s 22ms/step - loss: 0.4319 - val_loss: 0.1566

# %% [markdown]
# ### Attempt 4

# %%
from tensorflow.keras.callbacks import EarlyStopping
f.manual_forecast(call_me='lstm_24lags_earlystop_3layers',
                  lags=24,
                  epochs=25,
                  validation_split=.2,
                  shuffle=True,
                  callbacks=EarlyStopping(monitor='val_loss',
                                          patience=5),
                  lstm_layer_sizes=(16,16,16),
                  dropout=(0,0,0))
f.plot_test_set(ci=True)
# Out:
# Epoch 1/25
# 3/3 [==============================] - 7s 718ms/step - loss: 0.4646 - val_loss: 0.1891
# Epoch 2/25
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4512 - val_loss: 0.1789
# Epoch 3/25
# 3/3 [==============================] - 0s 44ms/step - loss: 0.4362 - val_loss: 0.1665
# Epoch 4/25
# 3/3 [==============================] - 0s 39ms/step - loss: 0.4177 - val_loss: 0.1507
# Epoch 5/25
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3932 - val_loss: 0.1324
# Epoch 6/25
# 3/3 [==============================] - 0s 39ms/step - loss: 0.3599 - val_loss: 0.1205
# Epoch 7/25
# 3/3 [==============================] - 0s 37ms/step - loss: 0.3208 - val_loss: 0.1334
# Epoch 8/25
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2922 - val_loss: 0.1694
# Epoch 9/25
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2815 - val_loss: 0.1885
# Epoch 10/25
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2699 - val_loss: 0.1723
# Epoch 11/25
# 3/3 [==============================] - 0s 37ms/step - loss: 0.2508 - val_loss: 0.1409
# Epoch 1/25
# 3/3 [==============================] - 7s 630ms/step - loss: 0.4508 - val_loss: 0.1708
# Epoch 2/25
# 3/3 [==============================] - 0s 34ms/step - loss: 0.4379 - val_loss: 0.1609
# Epoch 3/25
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4236 - val_loss: 0.1488
# Epoch 4/25
# 3/3 [==============================] - 0s 37ms/step - loss: 0.4057 - val_loss: 0.1337
# Epoch 5/25
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3816 - val_loss: 0.1168
# Epoch 6/25
# 3/3 [==============================] - 0s 36ms/step - loss: 0.3496 - val_loss: 0.1139
# Epoch 7/25
# 3/3 [==============================] - 0s 35ms/step - loss: 0.3129 - val_loss: 0.1327
# Epoch 8/25
# 3/3 [==============================] - 0s 36ms/step - loss: 0.2858 - val_loss: 0.1523
# Epoch 9/25
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2693 - val_loss: 0.1481
# Epoch 10/25
# 3/3 [==============================] - 0s 38ms/step - loss: 0.2478 - val_loss: 0.1323
# Epoch 11/25
# 3/3 [==============================] - 0s 39ms/step - loss: 0.2212 - val_loss: 0.1191

# %% [markdown]
# ### Attempt 5

# %%
f.manual_forecast(call_me='lstm_24lags_4layers_15epochs',
                  lags=36,
                  batch_size=32,
                  epochs=15,
                  validation_split=.2,
                  shuffle=True,
                  activation='tanh',
                  optimizer='Adam',
                  learning_rate=0.001,
                  lstm_layer_sizes=(72,)*4,
                  dropout=(0,)*4,
                  plot_loss=True)
f.plot_test_set(order_by='LevelTestSetMAPE',models='top_2',ci=True)
# Out:
# Epoch 1/15
# 3/3 [==============================] - 9s 866ms/step - loss: 0.4792 - val_loss: 0.1977
# Epoch 2/15
# 3/3 [==============================] - 0s 77ms/step - loss: 0.3732 - val_loss: 0.1061
# Epoch 3/15
# 3/3 [==============================] - 0s 87ms/step - loss: 0.2120 - val_loss: 0.1153
# Epoch 4/15
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1288 - val_loss: 0.0601
# Epoch 5/15
# 3/3 [==============================] - 0s 88ms/step - loss: 0.1311 - val_loss: 0.0830
# Epoch 6/15
# 3/3 [==============================] - 0s 89ms/step - loss: 0.1167 - val_loss: 0.0842
# Epoch 7/15
# 3/3 [==============================] - 0s 93ms/step - loss: 0.1038 - val_loss: 0.0532
# Epoch 8/15
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1010 - val_loss: 0.0529
# Epoch 9/15
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0934 - val_loss: 0.0557
# Epoch 10/15
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0935 - val_loss: 0.0523
# Epoch 11/15
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0900 - val_loss: 0.0548
# Epoch 12/15
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0887 - val_loss: 0.0565
# Epoch 13/15
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0882 - val_loss: 0.0624
# Epoch 14/15
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0900 - val_loss: 0.0603
# Epoch 15/15
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0915 - val_loss: 0.0573
# Epoch 1/15
# 3/3 [==============================] - 9s 891ms/step - loss: 0.4614 - val_loss: 0.1654
# Epoch 2/15
# 3/3 [==============================] - 0s 71ms/step - loss: 0.3306 - val_loss: 0.1431
# Epoch 3/15
# 3/3 [==============================] - 0s 77ms/step - loss: 0.2134 - val_loss: 0.0702
# Epoch 4/15
# 3/3 [==============================] - 0s 84ms/step - loss: 0.1165 - val_loss: 0.0726
# Epoch 5/15
# 3/3 [==============================] - 0s 90ms/step - loss: 0.1186 - val_loss: 0.1034
# Epoch 6/15
# 3/3 [==============================] - 0s 89ms/step - loss: 0.1090 - val_loss: 0.0516
# Epoch 7/15
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0983 - val_loss: 0.0501
# Epoch 8/15
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0931 - val_loss: 0.0490
# Epoch 9/15
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0896 - val_loss: 0.0489
# Epoch 10/15
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0886 - val_loss: 0.0474
# Epoch 11/15
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0864 - val_loss: 0.0531
# Epoch 12/15
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0860 - val_loss: 0.0502
# Epoch 13/15
# 3/3 [==============================] - 0s 104ms/step - loss: 0.0853 - val_loss: 0.0505
# Epoch 14/15
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0837 - val_loss: 0.0513
# Epoch 15/15
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0830 - val_loss: 0.0478

# %% [markdown]
# ### Attempt 6

# %%
f.manual_forecast(call_me='lstm_best',
                  lags=36,
                  batch_size=16,
                  epochs=300,
                  validation_split=.2,
                  shuffle=True,
                  activation='tanh',
                  optimizer='Adam',
                  learning_rate=0.001,
                  lstm_layer_sizes=(100,)*15,
                  dropout=(0,)*15,
                  plot_loss=True)
f.plot_test_set(order_by='LevelTestSetMAPE',models='top_2',ci=True)
# Out:
# Epoch 1/300
# 5/5 [==============================] - 35s 2s/step - loss: 0.4641 - val_loss: 0.2356
# Epoch 2/300
# 5/5 [==============================] - 2s 373ms/step - loss: 0.2414 - val_loss: 0.0997
# Epoch 3/300
# 5/5 [==============================] - 2s 402ms/step - loss: 0.1689 - val_loss: 0.3331
# Epoch 4/300
# 5/5 [==============================] - 2s 440ms/step - loss: 0.1542 - val_loss: 0.1602
# Epoch 5/300
# 5/5 [==============================] - 2s 398ms/step - loss: 0.1491 - val_loss: 0.2428
# Epoch 6/300
# 5/5 [==============================] - 2s 463ms/step - loss: 0.1448 - val_loss: 0.2517
# Epoch 7/300
# 5/5 [==============================] - 2s 440ms/step - loss: 0.1381 - val_loss: 0.1822
# Epoch 8/300
# 5/5 [==============================] - 2s 506ms/step - loss: 0.1426 - val_loss: 0.2186
# Epoch 9/300
# 5/5 [==============================] - 2s 434ms/step - loss: 0.1359 - val_loss: 0.2481
# Epoch 10/300
# 5/5 [==============================] - 2s 415ms/step - loss: 0.1352 - val_loss: 0.1775
# Epoch 11/300
# 5/5 [==============================] - 2s 398ms/step - loss: 0.1236 - val_loss: 0.0827
# Epoch 12/300
# 5/5 [==============================] - 2s 344ms/step - loss: 0.1030 - val_loss: 0.0626
# Epoch 13/300
# 5/5 [==============================] - 2s 360ms/step - loss: 0.1018 - val_loss: 0.0727
# Epoch 14/300
# 5/5 [==============================] - 2s 362ms/step - loss: 0.0989 - val_loss: 0.0580
# Epoch 15/300
# 2/5 [===========>..................] - ETA: 1s - loss: 0.0951
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-abfe7d3700de> in <module>
# ----> 1 f.manual_forecast(call_me='lstm_best',
#       2                   lags=36,
#       3                   batch_size=16,
#       4                   epochs=300,
#       5                   validation_split=.2,
#
# ~\Anaconda3\lib\site-packages\scalecast\Forecaster.py in manual_forecast(self, call_me, dynamic_testing, **kwargs)
#    2964             )
#    2965             if self.estimator in _sklearn_estimators_
# -> 2966             else getattr(self, f"_forecast_{self.estimator}")(
#    2967                 dynamic_testing=dynamic_testing, **kwargs
#    2968             )
#
# ~\Anaconda3\lib\site-packages\scalecast\Forecaster.py in _forecast_lstm(self, dynamic_testing, lags, lstm_layer_sizes, dropout, loss, activation, optimizer, learning_rate, random_seed, plot_loss, **kwargs)
#    1450
#    1451         test_model = get_compiled_model(y_train_new)
# -> 1452         test_model.fit(X_train,y_train_new,**kwargs)
#    1453         pred = test_model.predict(X_test)
#    1454
#
# ~\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## MLR Modeling

# %%
f.set_estimator('mlr')
f.add_ar_terms(24)
f.add_seasonal_regressors('month','quarter',dummy=True)
f.add_seasonal_regressors('year')
f.add_time_trend()
f.diff()

# %%
f.manual_forecast()
f.plot_test_set(order_by='LevelTestSetMAPE',models='top_2')

# %%
f.plot_test_set(models='mlr',ci=True)

# %%
f.plot(order_by='LevelTestSetMAPE',models='top_2')

# %% [markdown]
# ## Benchmarking

# %%
f.export('model_summaries',determine_best_by='LevelTestSetMAPE')[
    ['ModelNickname','LevelTestSetMAPE','LevelTestSetRMSE','LevelTestSetR2','best_model']
]

# %% [markdown]
# ## Export Results

# %%
f.export_forecasts_with_cis('mlr')

# %%
f.export_test_set_preds_with_cis('mlr')

# %% [markdown]
# ### Export Feature Info

# %%
f.save_feature_importance()
f.export_feature_importance('mlr')
